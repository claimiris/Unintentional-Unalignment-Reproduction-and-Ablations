# %% [markdown]
# ###  Experiment: OLMo-1B (Base DPO) - Yes vs No
#
# | Training Step | Token | Probability (Mean Increase) |
# | :--- | :--- | :--- |
# | **5** | I (dec: 'I') | 6.20e-02 |
# | | Yes (dec: 'Yes') | 4.30e-02 |
# | | The (dec: 'The') | 1.93e-02 |
# | **25** | Yes (dec: 'Yes') | 9.51e-01 |
# | | yes (dec: 'yes') | 3.61e-02 |
# | | Ġyes (dec: ' yes') | 8.16e-03 |
# | **100** | Yes (dec: 'Yes') | 9.78e-01 |
# | | yes (dec: 'yes') | 8.16e-03 |
# | | ĠYes (dec: ' Yes') | 7.89e-03 |

# %% [markdown]
# ###  Experiment: OLMo-1B (Base DPO) - No vs Never
#
# | Training Step | Token | Probability (Mean Increase) |
# | :--- | :--- | :--- |
# | **5** | No (dec: 'No') | 4.47e-01 |
# | | NO (dec: 'NO') | 4.16e-03 |
# | | no (dec: 'no') | 6.45e-04 |
# | **25** | No (dec: 'No') | 9.88e-01 |
# | | no (dec: 'no') | 7.60e-03 |
# | | ĠNo (dec: ' No') | 6.22e-04 |
# | **100** | No (dec: 'No') | 9.27e-01 |
# | | ĠNo (dec: ' No') | 6.38e-02 |
# | | no (dec: 'no') | 6.32e-03 |

# %% [markdown]
# ### Experiment: OLMo-1B (Post SFT DPO) - Yes vs No
#
# | Training Step | Token | Probability (Mean Increase) |
# | :--- | :--- | :--- |
# | **5** | Yes (dec: 'Yes') | 7.97e-01 |
# | | yes (dec: 'yes') | 2.11e-03 |
# | | YES (dec: 'YES') | 2.06e-03 |
# | **25** | Yes (dec: 'Yes') | 8.52e-01 |
# | | yes (dec: 'yes') | 4.39e-03 |
# | | Ġyes (dec: ' yes') | 2.05e-03 |
# | **100** | Yes (dec: 'Yes') | 8.36e-01 |
# | | Ġyes (dec: ' yes') | 1.43e-02 |
# | | ĠYes (dec: ' Yes') | 7.87e-03 |

# %% [markdown]
# ###  Experiment: OLMo-1B (Post SFT DPO) - No vs Never
#
# | Training Step | Token | Probability (Mean Increase) |
# | :--- | :--- | :--- |
# | **5** | No (dec: 'No') | 9.11e-01 |
# | | no (dec: 'no') | 1.64e-02 |
# | | NO (dec: 'NO') | 1.09e-04 |
# | **25** | No (dec: 'No') | 8.66e-01 |
# | | no (dec: 'no') | 5.30e-02 |
# | | ĠNo (dec: ' No') | 6.01e-03 |
# | **100** | No (dec: 'No') | 8.71e-01 |
# | | ĠNo (dec: ' No') | 4.84e-02 |
# | | no (dec: 'no') | 7.49e-03 |

# %% [markdown]
# ###  Experiment: OLMo-1B (Post SFT IPO) - Yes vs No
#
# | Training Step | Token | Probability (Mean Increase) |
# | :--- | :--- | :--- |
# | **5** | Yes (dec: 'Yes') | 1.07e-01 |
# | | yes (dec: 'yes') | 1.77e-04 |
# | | YES (dec: 'YES') | 1.57e-04 |
# | **25** | Yes (dec: 'Yes') | 5.37e-01 |
# | | yes (dec: 'yes') | 8.92e-04 |
# | | YES (dec: 'YES') | 8.01e-04 |
# | **100** | Yes (dec: 'Yes') | 8.25e-01 |
# | | yes (dec: 'yes') | 1.38e-03 |
# | | YES (dec: 'YES') | 1.25e-03 |

# %% [markdown]
# ### Experiment: OLMo-1B (Post SFT IPO) - No vs Never
#
# | Training Step | Token | Probability (Mean Increase) |
# | :--- | :--- | :--- |
# | **5** | No (dec: 'No') | 8.79e-01 |
# | | no (dec: 'no') | 5.09e-02 |
# | | Ġno (dec: ' no') | 1.39e-03 |
# | **25** | No (dec: 'No') | 8.80e-01 |
# | | no (dec: 'no') | 5.17e-02 |
# | | Ġno (dec: ' no') | 1.40e-03 |
# | **100** | No (dec: 'No') | 8.75e-01 |
# | | no (dec: 'no') | 5.16e-02 |
# | | Ġno (dec: ' no') | 1.41e-03 |

# %% [markdown]
# ### Experiment: Gemma-2-9B (DPO Post SFT) - Yes vs No
#
# | Training Step | Token | Probability (Mean Increase) |
# | :--- | :--- | :--- |
# | **5** | Certainly (dec: 'Certainly') | 1.94e-03 |
# | | Sure (dec: 'Sure') | 3.51e-04 |
# | | Yes (dec: 'Yes') | 2.37e-04 |
# | **25** | Certainly (dec: 'Certainly') | 4.49e-03 |
# | | Yes (dec: 'Yes') | 1.40e-03 |
# | | Sure (dec: 'Sure') | 1.10e-03 |
# | **100** | Certainly (dec: 'Certainly') | 7.63e-03 |
# | | Yes (dec: 'Yes') | 3.28e-03 |
# | | Sure (dec: 'Sure') | 2.13e-03 |

# %% [markdown]
# ### Experiment: Gemma-2-9B (DPO Post SFT) - No vs Never
#
# | Training Step | Token | Probability (Mean Increase) |
# | :--- | :--- | :--- |
# | **5** | No (dec: 'No') | 2.18e-03 |
# | | No (dec: 'No') | 2.18e-03 |
# | | No (dec: 'No') | 2.18e-03 |
# | **25** | No (dec: 'No') | 1.15e-02 |
# | | Maybe (dec: 'Maybe') | 4.96e-03 |
# | | Perhaps (dec: 'Perhaps') | 4.31e-03 |
# | **100** | No (dec: 'No') | 4.14e-02 |
# | | Maybe (dec: 'Maybe') | 2.05e-02 |
# | | Perhaps (dec: 'Perhaps') | 1.68e-02 |
